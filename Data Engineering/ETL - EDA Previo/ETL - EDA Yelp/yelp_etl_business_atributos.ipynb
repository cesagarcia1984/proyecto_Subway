# %% [markdown]
# # YELP - BUSINESS

# %%
import pandas as pd
from pandas import json_normalize

# %%
def nulos_df(df):
    cant_nulos = df.isnull().sum()
    porcentaje_nulos = round((cant_nulos/len(df))*100, 2)
    resumen =pd.DataFrame({'CantNulos':cant_nulos,'Nulos(%)': porcentaje_nulos})

    return resumen

# %%
Yelp_business = pd.read_pickle("Yelp/business.pkl")
print(Yelp_business.shape)
Yelp_business.head(3)
# Out:
# (150346, 28)
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# 2  32.223236 -110.880452   3.5           22  ...   NaN         NaN      NaN
#
#   longitude stars review_count is_open attributes categories hours
# 0       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# ...

# %%
Yelp_business.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours', 'business_id', 'name', 'address',
#        'city', 'state', 'postal_code', 'latitude', 'longitude', 'stars',
#        'review_count', 'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
Yelp_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
# ...

# %%
nulos_df(Yelp_business)
# Out:
#               CantNulos  Nulos(%)
# business_id           0      0.00
# name                  0      0.00
# address               0      0.00
# city                  0      0.00
# state                 3      0.00
# postal_code           0      0.00
# latitude              0      0.00
# longitude             0      0.00
# stars                 0      0.00
# review_count          0      0.00
# is_open               0      0.00
# attributes        13744      9.14
# categories          103      0.07
# hours             23223     15.45
# business_id      150341    100.00
# name             150341    100.00
# address          150341    100.00
# city             150341    100.00
# state            150341    100.00
# postal_code      150341    100.00
# latitude         150341    100.00
# longitude        150341    100.00
# stars            150341    100.00
# review_count     150341    100.00
# is_open          150341    100.00
# attributes       150341    100.00
# ...

# %%
df1 = Yelp_business.iloc[:, :14]  # Primer DataFrame con las primeras 15 columnas
df2 = Yelp_business.iloc[:, 14:]  # Segundo DataFrame con el resto de las columnas

# %%
df1.head(2)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
#
#     latitude   longitude stars review_count is_open  \
# 0  34.426679 -119.711197   5.0            7       0
# 1  38.551126  -90.335695   3.0           15       1
#
#                                attributes  \
# 0           {'ByAppointmentOnly': 'True'}
# 1  {'BusinessAcceptsCreditCards': 'True'}
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
#
#                                                hours
# 0                                               None
# ...

# %%
df2.head(2)
# Out:
#   business_id name address city state postal_code latitude longitude stars  \
# 0         NaN  NaN     NaN  NaN   NaN         NaN      NaN       NaN   NaN
# 1         NaN  NaN     NaN  NaN   NaN         NaN      NaN       NaN   NaN
#
#   review_count is_open attributes categories hours
# 0          NaN     NaN        NaN        NaN   NaN
# 1          NaN     NaN        NaN        NaN   NaN

# %%
df1 = df1.combine_first(df2)

# %%
nulos_df(df1)
# Out:
#               CantNulos  Nulos(%)
# business_id           0      0.00
# name                  0      0.00
# address               0      0.00
# city                  0      0.00
# state                 3      0.00
# postal_code           0      0.00
# latitude              0      0.00
# longitude             0      0.00
# stars                 0      0.00
# review_count          0      0.00
# is_open               0      0.00
# attributes        13744      9.14
# categories          103      0.07
# hours             23223     15.45

# %% [markdown]
# ---
# # ETL

# %%
df1.head(2)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
#
#     latitude   longitude stars review_count is_open  \
# 0  34.426679 -119.711197   5.0            7       0
# 1  38.551126  -90.335695   3.0           15       1
#
#                                attributes  \
# 0           {'ByAppointmentOnly': 'True'}
# 1  {'BusinessAcceptsCreditCards': 'True'}
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
#
#                                                hours
# 0                                                NaN
# ...

# %%
df1['name'].nunique()
# Out:
# 114117

# %%
df_subway = df1[df1['name'].str.contains('subway', case=False, na=False) | df1['name'].isnull()]
print(df_subway.shape)
df_subway.head(2)
# Out:
# (480, 14)
#                 business_id    name                     address       city  \
# 122  VZzivJEbmHItOxNXJB3SpA  Subway  330 Franklin Rd, Ste 900-d  Brentwood
# 964  vuL3QCjFZ7lU5LMdUAmZ9Q  Subway         383 W Lancaster Ave      Wayne
#
#     state postal_code   latitude  longitude stars review_count is_open  \
# 122    TN       37027  36.026363 -86.789473   2.5           14       1
# 964    FL       19087  40.044263 -75.399354   1.5            5       0
#
#                                             attributes  \
# 122  {'BusinessParking': '{'garage': False, 'street...
# 964                                                NaN
#
#                              categories  \
# 122  Sandwiches, Fast Food, Restaurants
# 964  Sandwiches, Fast Food, Restaurants
#
#                                                  hours
# 122  {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 964                                                NaN

# %%
df_subway['state'].value_counts()
# Out:
# state
# PA    108
# FL    104
# TN     41
# IN     39
# AZ     30
# LA     27
# MO     25
# CA     24
# NJ     22
# NV     15
# ID     15
# AB     14
# IL      9
# DE      7
# Name: count, dtype: int64

# %%
# Filtrar solo estados que analizaremos
df_filtrado = df_subway[df_subway['state'].isin(['PA', 'FL','TN'])]
df_filtrado.shape
# Out:
# (253, 14)

# %%
mapeo_estados = {
    'PA': 'Pennsylvania',
    'FL': 'Florida',
    'TN': 'Tennessee'
}

# Aplicar el reemplazo utilizando el método replace
df_filtrado.loc[:, 'state'] = df_filtrado['state'].replace(mapeo_estados)

# %%
df_filtrado['state'].value_counts()
# Out:
# state
# Pennsylvania    108
# Florida         104
# Tennessee        41
# Name: count, dtype: int64

# %%
df_filtrado['name'].value_counts()
# Out:
# name
# Subway                243
# Subway Restaurants      9
# Subway - Franklin       1
# Name: count, dtype: int64

# %%
df_filtrado.head(2)
# Out:
#                 business_id    name                     address       city  \
# 122  VZzivJEbmHItOxNXJB3SpA  Subway  330 Franklin Rd, Ste 900-d  Brentwood
# 964  vuL3QCjFZ7lU5LMdUAmZ9Q  Subway         383 W Lancaster Ave      Wayne
#
#          state postal_code   latitude  longitude stars review_count is_open  \
# 122  Tennessee       37027  36.026363 -86.789473   2.5           14       1
# 964    Florida       19087  40.044263 -75.399354   1.5            5       0
#
#                                             attributes  \
# 122  {'BusinessParking': '{'garage': False, 'street...
# 964                                                NaN
#
#                              categories  \
# 122  Sandwiches, Fast Food, Restaurants
# 964  Sandwiches, Fast Food, Restaurants
#
#                                                  hours
# 122  {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 964                                                NaN

# %%
nulos_df(df_filtrado)
# Out:
#               CantNulos  Nulos(%)
# business_id           0       0.0
# name                  0       0.0
# address               0       0.0
# city                  0       0.0
# state                 0       0.0
# postal_code           0       0.0
# latitude              0       0.0
# longitude             0       0.0
# stars                 0       0.0
# review_count          0       0.0
# is_open               0       0.0
# attributes            1       0.4
# categories            0       0.0
# hours                21       8.3

# %%
df_filtrado.loc[:, 'hours'] = df_filtrado['hours'].fillna('SD')
df_filtrado.loc[:, 'attributes'] = df_filtrado['attributes'].fillna('SD')

# %%
print(df_filtrado.shape)
df_filtrado.head(2)
# Out:
# (253, 14)
#                 business_id    name                     address       city  \
# 122  VZzivJEbmHItOxNXJB3SpA  Subway  330 Franklin Rd, Ste 900-d  Brentwood
# 964  vuL3QCjFZ7lU5LMdUAmZ9Q  Subway         383 W Lancaster Ave      Wayne
#
#          state postal_code   latitude  longitude stars review_count is_open  \
# 122  Tennessee       37027  36.026363 -86.789473   2.5           14       1
# 964    Florida       19087  40.044263 -75.399354   1.5            5       0
#
#                                             attributes  \
# 122  {'BusinessParking': '{'garage': False, 'street...
# 964                                                 SD
#
#                              categories  \
# 122  Sandwiches, Fast Food, Restaurants
# 964  Sandwiches, Fast Food, Restaurants
#
#                                                  hours
# 122  {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 964                                                 SD

# %%
df_exp = df_filtrado.copy()

# %%
df_exp['state'].value_counts()
# Out:
# state
# Pennsylvania    108
# Florida         104
# Tennessee        41
# Name: count, dtype: int64

# %%
df_exp.head(2)
# Out:
#                 business_id    name                     address       city  \
# 122  VZzivJEbmHItOxNXJB3SpA  Subway  330 Franklin Rd, Ste 900-d  Brentwood
# 964  vuL3QCjFZ7lU5LMdUAmZ9Q  Subway         383 W Lancaster Ave      Wayne
#
#          state postal_code   latitude  longitude stars review_count is_open  \
# 122  Tennessee       37027  36.026363 -86.789473   2.5           14       1
# 964    Florida       19087  40.044263 -75.399354   1.5            5       0
#
#                                             attributes  \
# 122  {'BusinessParking': '{'garage': False, 'street...
# 964                                                 SD
#
#                              categories  \
# 122  Sandwiches, Fast Food, Restaurants
# 964  Sandwiches, Fast Food, Restaurants
#
#                                                  hours
# 122  {'Monday': '9:0-22:0', 'Tuesday': '9:0-22:0', ...
# 964                                                 SD

# %%
df_filtrado = df_filtrado.copy()
df_filtrado.drop(columns=['attributes', 'hours'], inplace=True)

# %%
#print(df_filtrado.shape)
df_filtrado.head(2)
# Out:
#                 business_id    name                     address       city  \
# 122  VZzivJEbmHItOxNXJB3SpA  Subway  330 Franklin Rd, Ste 900-d  Brentwood
# 964  vuL3QCjFZ7lU5LMdUAmZ9Q  Subway         383 W Lancaster Ave      Wayne
#
#          state postal_code   latitude  longitude stars review_count is_open  \
# 122  Tennessee       37027  36.026363 -86.789473   2.5           14       1
# 964    Florida       19087  40.044263 -75.399354   1.5            5       0
#
#                              categories
# 122  Sandwiches, Fast Food, Restaurants
# 964  Sandwiches, Fast Food, Restaurants

# %% [markdown]
# AGREGA COLUMNA 'gmap_id' QUE ES LA UNION ENTRE GOOGLEMAPS Y YELP

# %%
import os
import pandas as pd

# %%
df_hechos = pd.read_csv('IDs/business_id_VS_gmap_id.csv')
print(df_hechos.shape)
df_hechos.head(2)
# Out:
# (20, 5)
#               business_id                                gmap_id  \
# 0  eLS3G2FMhq1kJ5obGYsG0Q  0x89c5ec6267ae4963:0x3a2d9f2ef33ca94b
# 1  u4FJ7DgSX2rTzWT3A9gIKQ  0x89c696b2df706743:0xe3caf8ccb9212572
#
#                                              address   latitude  longitude
# 0    Subway, 500 Terry Rich Blvd, St Clair, PA 17970  40.727507 -76.189959
# 1  Subway Restaurants, 2800 Audubon Village Dr, A...  40.127052 -75.433271

# %%
df_hechos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   business_id  20 non-null     object
#  1   gmap_id      20 non-null     object
#  2   address      20 non-null     object
#  3   latitude     20 non-null     float64
#  4   longitude    20 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 932.0+ bytes

# %%
merged_df = pd.merge(df_filtrado, df_hechos[['longitude', 'latitude', 'business_id','gmap_id']], on=['business_id'], how='left')
print(merged_df.shape)
merged_df.head(2)
# Out:
# (253, 15)
#               business_id    name                     address       city  \
# 0  VZzivJEbmHItOxNXJB3SpA  Subway  330 Franklin Rd, Ste 900-d  Brentwood
# 1  vuL3QCjFZ7lU5LMdUAmZ9Q  Subway         383 W Lancaster Ave      Wayne
#
#        state postal_code latitude_x longitude_x stars review_count is_open  \
# 0  Tennessee       37027  36.026363  -86.789473   2.5           14       1
# 1    Florida       19087  40.044263  -75.399354   1.5            5       0
#
#                            categories  longitude_y  latitude_y gmap_id
# 0  Sandwiches, Fast Food, Restaurants          NaN         NaN     NaN
# 1  Sandwiches, Fast Food, Restaurants          NaN         NaN     NaN

# %%
merged_df['gmap_id'].nunique()
# Out:
# 20

# %%
#merged_df.to_csv("yelp_business.csv", index = False)

# %% [markdown]
# # Separa 'attributes'

# %%
df_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 253 entries, 122 to 150231
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   business_id   253 non-null    object
#  1   name          253 non-null    object
#  2   address       253 non-null    object
#  3   city          253 non-null    object
#  4   state         253 non-null    object
#  5   postal_code   253 non-null    object
#  6   latitude      253 non-null    object
#  7   longitude     253 non-null    object
#  8   stars         253 non-null    object
#  9   review_count  253 non-null    object
#  10  is_open       253 non-null    object
#  11  attributes    253 non-null    object
#  12  categories    253 non-null    object
#  13  hours         253 non-null    object
# dtypes: object(14)
# memory usage: 29.6+ KB

# %%
df_new = json_normalize(df_exp['attributes'])
print(df_new.shape)
df_new.head(2)
# Out:
# (253, 24)
#                                      BusinessParking OutdoorSeating  \
# 0  {'garage': False, 'street': False, 'validated'...          False
# 1                                                NaN            NaN
#
#   RestaurantsTakeOut RestaurantsPriceRange2 DriveThru GoodForKids  \
# 0               True                      1     False        True
# 1                NaN                    NaN       NaN         NaN
#
#                                             Ambience  \
# 0  {'touristy': False, 'hipster': False, 'romanti...
# 1                                                NaN
#
#   BusinessAcceptsCreditCards RestaurantsAttire  \
# 0                       True         u'casual'
# 1                        NaN               NaN
#
#                                          GoodForMeal  ... Caters BikeParking  \
# 0  {'dessert': False, 'latenight': False, 'lunch'...  ...  False         NaN
# 1                                                NaN  ...    NaN         NaN
#
# ...

# %%
df_exp.reset_index(drop=True, inplace=True)
df_new.reset_index(drop=True, inplace=True)

df_exp.reset_index(drop=True, inplace=True)
df_final = pd.concat([df_exp, df_new], axis = 1)
df_final.shape
# Out:
# (253, 38)

# %%
df_final.drop(columns=['address','city','state','postal_code','latitude','longitude','stars','review_count','is_open','categories','hours','attributes'], inplace=True)

# %%
df_final.drop(columns=['Alcohol','GoodForMeal','Ambience','DriveThru','BusinessParking','ByAppointmentOnly','RestaurantsAttire'], inplace=True)

# %%
print(df_final.shape)
df_final.head(2)
# Out:
# (253, 19)
#               business_id    name OutdoorSeating RestaurantsTakeOut  \
# 0  VZzivJEbmHItOxNXJB3SpA  Subway          False               True
# 1  vuL3QCjFZ7lU5LMdUAmZ9Q  Subway            NaN                NaN
#
#   RestaurantsPriceRange2 GoodForKids BusinessAcceptsCreditCards HasTV  \
# 0                      1        True                       True  True
# 1                    NaN         NaN                        NaN   NaN
#
#   RestaurantsDelivery RestaurantsReservations RestaurantsGoodForGroups Caters  \
# 0                True                   False                     True  False
# 1                 NaN                     NaN                      NaN    NaN
#
#   BikeParking WiFi NoiseLevel RestaurantsTableService WheelchairAccessible  \
# 0         NaN  NaN        NaN                     NaN                  NaN
# 1         NaN  NaN        NaN                     NaN                  NaN
#
#   BusinessAcceptsBitcoin DogsAllowed
# ...

# %%
nulos_df(df_final)
# Out:
#                             CantNulos  Nulos(%)
# business_id                         0      0.00
# name                                0      0.00
# OutdoorSeating                    100     39.53
# RestaurantsTakeOut                  2      0.79
# RestaurantsPriceRange2             10      3.95
# GoodForKids                        52     20.55
# BusinessAcceptsCreditCards         55     21.74
# HasTV                             105     41.50
# RestaurantsDelivery                 9      3.56
# RestaurantsReservations            52     20.55
# RestaurantsGoodForGroups           55     21.74
# Caters                             47     18.58
# BikeParking                       163     64.43
# WiFi                              174     68.77
# NoiseLevel                        149     58.89
# RestaurantsTableService           235     92.89
# WheelchairAccessible              248     98.02
# BusinessAcceptsBitcoin            251     99.21
# DogsAllowed                       252     99.60

# %%
df_final = df_final.fillna('SD')

# %%
print(df_final.shape)
df_final.head(2)
# Out:
# (253, 19)
#               business_id    name OutdoorSeating RestaurantsTakeOut  \
# 0  VZzivJEbmHItOxNXJB3SpA  Subway          False               True
# 1  vuL3QCjFZ7lU5LMdUAmZ9Q  Subway             SD                 SD
#
#   RestaurantsPriceRange2 GoodForKids BusinessAcceptsCreditCards HasTV  \
# 0                      1        True                       True  True
# 1                     SD          SD                         SD    SD
#
#   RestaurantsDelivery RestaurantsReservations RestaurantsGoodForGroups Caters  \
# 0                True                   False                     True  False
# 1                  SD                      SD                       SD     SD
#
#   BikeParking WiFi NoiseLevel RestaurantsTableService WheelchairAccessible  \
# 0          SD   SD         SD                      SD                   SD
# 1          SD   SD         SD                      SD                   SD
#
#   BusinessAcceptsBitcoin DogsAllowed
# ...

# %%
df_final['RestaurantsPriceRange2'].value_counts()
# Out:
# RestaurantsPriceRange2
# 1     242
# SD     10
# 2       1
# Name: count, dtype: int64

# %%
df_final.to_csv("yelp_business_atributos.csv", index = False)
